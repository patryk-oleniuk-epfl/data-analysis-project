# %%
import requests
import json
import time
from datetime import date
from datetime import datetime
from helpers.history_fetcher import HistoryFetcher
import dateutil.parser
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import gdelt # pip install gdelt
import folium
import os
from tqdm import tqdm_notebook # conda install tqdm
import operator
from helpers.wiki_helpers import get_stability_for_country, make_folium_map, wiki_change_factor

import warnings
warnings.filterwarnings('ignore')

import itertools

# %load_ext autoreload
# %autoreload 2

pd.options.mode.chained_assignment = None
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Gather GDELT data
# #### EXECUTE ONLY ON THE SERVER (memory issues)

# %%
### this code is executed on the big server to obtain the results from 2011 to 2018 divided into 3 files per year
### for size.

import numpy as np
import pandas as pd
import gdelt # pip install gdelt
import gc

gd1 = gdelt.gdelt(version=1)
for i in range(11, 18):
    print('year : ', i , 1)
    results = gd1.Search(['20'+str(i)+' January 01','20'+str(i)+' May 01'],table='events')
    cols_to_keep = ['SQLDATE','ActionGeo_CountryCode','QuadClass' ]
    results = results[cols_to_keep]
    pd.to_pickle(results, 'gdelt_filtered_QuadClass_20'+str(i)+'_1.pckl')
    del results
    gc.collect()
    print('year : ', i , 2)
    results = gd1.Search(['20'+str(i)+' May 01','20'+str(i)+' August 01'],table='events')
    results = results[cols_to_keep]
    pd.to_pickle(results, 'gdelt_filtered_QuadClass_20'+str(i)+'_2.pckl')
    del results
    gc.collect()
    print('year : ', i , 3)
    if(i != 17):
        results = gd1.Search(['20'+str(i)+' August 01','20'+str(i+1)+' January 01'],table='events')
    else:
        results = gd1.Search(['20'+str(i)+' August 01','20'+str(i)+' December 01'],table='events')
    results = results[cols_to_keep]
    pd.to_pickle(results, 'gdelt_filtered_QuadClass_20'+str(i)+'_3.pckl')
    del results
    gc.collect()

# %% [markdown]
# ### Process GDELT Data (aggregate)
# #### EXECUTE ONLY ON THE SERVER (memory issues)

# %%
from os import listdir
from os.path import isfile, join
import gc

def process_files():
    onlyfiles = [f for f in listdir('.') if isfile(join('.', f))]
    
    grouped = pd.DataFrame()
    for i, file in enumerate(onlyfiles):
        print('processing ', file)
        gc.collect()
        try:
            data = pd.read_pickle(file)
            data['Counter'] = 1.0
            data = data[['SQLDATE','ActionGeo_CountryCode', 'QuadClass', 'Counter']]
        except:
            continue;
        grouped = grouped.append([data.groupby(['SQLDATE','ActionGeo_CountryCode', 'QuadClass']).sum()])
        pd.to_pickle(grouped, str(i)+'_QuadClass.pckl')
        del data

# %% [markdown]
# ### Show the gathered data, save to the aggregated pickle file

# %%
QuadClass_event_dic = {1:'Verbal Cooperation', 
                   2:'Material Cooperation', 
                   3:'Verbal Conflict', 
                   4:'Material Conflict', 
                   np.NaN:'',
                   0:'UNKNOWN'}


aggregated_gdelt = pd.read_pickle('data/20_QuadClass.pckl')
# clean the dataframe
aggregated_gdelt.reset_index(inplace=True)
# change names
aggregated_gdelt['QuadClass'] = aggregated_gdelt['QuadClass'].map(QuadClass_event_dic)
aggregated_gdelt.sort_values('SQLDATE', inplace=True)
# take only values above 2011
aggregated_gdelt = aggregated_gdelt[aggregated_gdelt['SQLDATE'] > 20110101]
# convert to Timestamp (takes lots of time)
aggregated_gdelt['SQLDATE'] = aggregated_gdelt['SQLDATE'].apply(lambda x: str(x) )
aggregated_gdelt['SQLDATE'] = aggregated_gdelt['SQLDATE'].apply(lambda x: pd.Timestamp(x).to_pydatetime())
pd.to_pickle(aggregated_gdelt, 'data/aggregated_gdelt_QuadClass.pckl')
aggregated_gdelt.head(20)
# Out:
#           SQLDATE ActionGeo_CountryCode             QuadClass  Counter
# 151776 2011-01-02                    NL     Material Conflict     27.0
# 151778 2011-01-02                    NO  Material Cooperation      4.0
# 151779 2011-01-02                    NO       Verbal Conflict     11.0
# 151777 2011-01-02                    NO    Verbal Cooperation     41.0
# 151780 2011-01-02                    NO     Material Conflict     12.0
# 151781 2011-01-02                    NP    Verbal Cooperation    140.0
# 151782 2011-01-02                    NP  Material Cooperation     18.0
# 151783 2011-01-02                    NP       Verbal Conflict     39.0
# 151757 2011-01-02                    MX       Verbal Conflict     33.0
# 151785 2011-01-02                    NS    Verbal Cooperation      2.0
# 151786 2011-01-02                    NS  Material Cooperation      1.0
# 151787 2011-01-02                    NU    Verbal Cooperation      8.0
# 151788 2011-01-02                    NZ    Verbal Cooperation    170.0
# 151775 2011-01-02                    NL       Verbal Conflict     10.0
# 151789 2011-01-02                    NZ  Material Cooperation     39.0
# 151790 2011-01-02                    NZ       Verbal Conflict      7.0
# 151784 2011-01-02                    NP     Material Conflict     31.0
# 151774 2011-01-02                    NL  Material Cooperation     20.0
# 151758 2011-01-02                    MX     Material Conflict     97.0
# 151772 2011-01-02                    NI     Material Conflict    185.0

# %% [markdown]
# ### Combining all the UNData frames together basic info about the countries)

# %%
nr_internet_people = pd.read_csv('data/nr_people_internet.csv')
cols_to_keep = ['Country or Area','Value']
nr_internet_people = nr_internet_people[cols_to_keep]
nr_internet_people.columns=['Country','Internet Users%']
nr_internet_people.set_index('Country',inplace=True)

nr_all_people = pd.read_csv('data/nr_people_all.csv')
nr_all_people = nr_all_people[nr_all_people['Variant']=='Medium'][cols_to_keep]
cols_to_keep = ['Country or Area','Value']
nr_all_people = nr_all_people[cols_to_keep]
nr_all_people.columns=['Country','Population[k]']
nr_all_people.set_index('Country',inplace=True)

population_data = pd.concat([nr_all_people, nr_internet_people], axis=1, join='inner')
population_data['Internet users[k]'] = population_data['Population[k]'] * population_data['Internet Users%']/100
population_data.head(5)


countries_data = pd.read_csv('data/country-codes.csv')[1:]
cols_to_keep = ['official_name_en','ISO3166-1-Alpha-3','ISO3166-1-Alpha-2' ,'Least Developed Countries (LDC)','Region Name',
                'Small Island Developing States (SIDS)', 'is_independent']
countries_data = countries_data[cols_to_keep]

cols_to_keep = ['official_name_en','ISO3166-1-Alpha-3','ISO3166-1-Alpha-2' ,'Region Name']

countries_data = countries_data[cols_to_keep]
countries_data.columns = ['Country', 'Code','Code2','Region']
countries_data['Wiki Stability MLE'] = np.NaN;
countries_data['Wiki Instability old'] = np.NaN;
countries_data['Wiki mean change day'] = np.NaN;
countries_data.set_index('Country',inplace=True)


countries_data = pd.concat([countries_data, population_data], axis=1, join='inner')
countries_data['Big Internet'] = countries_data['Internet users[k]'] > 1000
countries_data.reset_index(inplace=True)

gdp_data = pd.read_csv('data/UNdata_GDP.csv')
keep_cols = ['Country or Area', 'Value']

gdp_data = gdp_data[keep_cols]
gdp_data.columns = ['Country', 'GDP']
gdp_data.set_index('Country', inplace=True)
#countries_data.reset_index(inplace=True)
countries_data.set_index('Country', inplace=True)
countries_data = pd.concat([countries_data, gdp_data], axis=1, join='inner')
countries_data.reset_index(inplace=True)

countries_data['GDP per capita'] = countries_data['GDP'] / countries_data['Population[k]']

countries_data.head()
# Out:
#        Country Code Code2  Region  Wiki Stability MLE  Wiki Instability old  \
# 0  Afghanistan  AFG    AF    Asia                 NaN                   NaN
# 1      Albania  ALB    AL  Europe                 NaN                   NaN
# 2      Algeria  DZA    DZ  Africa                 NaN                   NaN
# 3      Andorra  AND    AD  Europe                 NaN                   NaN
# 4       Angola  AGO    AO  Africa                 NaN                   NaN
#
#    Wiki mean change day  Population[k]  Internet Users%  Internet users[k]  \
# 0                   NaN      35530.081         8.260000        2934.784691
# 1                   NaN       2930.187        63.252933        1853.429211
# 2                   NaN      41318.142        38.200000       15783.530244
# 3                   NaN         76.965        96.910000          74.586782
# 4                   NaN      29784.193        12.400000        3693.239932
#
#    Big Internet           GDP  GDP per capita
# 0          True    623.184798        0.017540
# 1          True   3984.234302        1.359720
# 2          True   4154.118319        0.100540
# 3         False  39896.376936      518.370388
# 4          True   4714.065956        0.158274

# %% [markdown]
# ### Gathering the stability / instability data (#1 and #2) into the countries_data dataframe
# #### saving file every iteration,
# #### it takes ~ 3h to fetch all the data from the internet

# %%
countries_data = pd.read_pickle('datacountries_data.pckl')
countries = countries_data['Country'].values

countries[countries == 'Syrian Arab Republic'] = 'Syria'
countries[163] = 'United States'


codes = countries_data['Code'].values

for i in tqdm_notebook(range(len(countries))):
    # if not already fetched
    
    start = '20130101000000'
    stop = '20171101000000'
    try:
        if((np.isnan(countries_data[countries_data['Country']==countries[i] ]['Wiki Stability MLE'].values[0]))):
            print('fetching',countries[i])
            stab_factor, mean = get_stability_for_country( countries[i], start, stop)
            instab_factor = wiki_change_factor( countries[i], 2013, 2017, outlier_factor=3.4) 
            print(countries[i],'stab:',stab_factor,'instab',instab_factor,'mean', mean)
            countries_data[i:i+1]['Wiki Stability MLE'] = stab_factor
            countries_data[i:i+1]['Wiki Instability old'] = instab_factor
            countries_data[i:i+1]['Wiki mean change day'] = mean
            # save the values every time
            pd.to_pickle(countries_data, 'data/countries_data.pckl')
            
        else:
            print(countries[i],'Done already')
    except KeyError:
        break;
    except:
        print('skipped: ',countries[i], e)
# Out:
# Processing  AA - Aruba
# Processed  Aruba corr :  0.00297966381665
# Processing  AC - Antigua and Barbuda
# Processed  Antigua and Barbuda corr :  0.244411343431
# Processing  AE - United Arab Emirates
# Processed  United Arab Emirates corr :  0.0230502608718
# Processing  AF - Afghanistan
# Processed  Afghanistan corr :  0.15006895486
# Processing  AG - Algeria
# Processed  Algeria corr :  0.512626335958
# Processing  AJ - Azerbaijan
# Processed  Azerbaijan corr :  0.144147357664
# Processing  AL - Albania
# Processed  Albania corr :  0.0437615519295
# Processing  AM - Armenia
# Processed  Armenia corr :  0.000452808221881
# Processing  AN - Andorra
# Processed  Andorra corr :  0.0558129880402
# Processing  AO - Angola
# Processed  Angola corr :  0.220731012676
# Processing  AR - Argentina
# Processed  Argentina corr :  0.00176887707684
# Processing  AS - Australia
# Processed  Australia corr :  0.215757339925
# Processing  AU - Austria
# Processed  Austria corr :  0.190185443348
# Processing  AV - nan
# Processed  AV  NaN CODE
# Processing  AY -
# Processed  AY  NaN CODE
# Processing  BA - Bahrain
# Processed  Bahrain corr :  0.113609987772
# Processing  BB - Barbados
# Processed  Barbados corr :  0.143960263882
# Processing  BC - Botswana
# Processed  Botswana corr :  0.128863734902
# Processing  BD - Bermuda
# Processed  Bermuda corr :  0.186049570808
# Processing  BE - Belgium
# Processed  Belgium corr :  0.0530350617261
# Processing  BG - Bangladesh
# Processed  Bangladesh corr :  0.374244035856
# Processing  BH - Belize
# Processed  Belize corr :  0.340087082781
# Processing  BK - Bosnia and Herzegovina
# Processed  Bosnia and Herzegovina corr :  0.00014876753991
# Processing  BM - Myanmar
# Processed  Myanmar corr :  0.0028318040756
# Processing  BN - Benin
# Processed  Benin corr :  0.192169671418
# Processing  BO - Belarus
# Processed  Belarus corr :  0.0237681038762
# Processing  BP - Solomon Islands
# Processed  Solomon Islands corr :  0.000204764123305
# Processing  BR - Brazil
# Processed  Brazil corr :  0.153141010371
# Processing  BT - Bhutan
# Processed  Bhutan corr :  0.176810171734
# Processing  BU - Bulgaria
# Processed  Bulgaria corr :  0.086842246615
# Processing  BX - Brunei Darussalam
# Processed  Brunei Darussalam corr :  0.0146762831702
# Processing  BY - Burundi
# Processed  Burundi corr :  0.606107515179
# Processing  CA - Canada
# Processed  Canada corr :  0.101616414638
# Processing  CB - Cambodia
# Processed  Cambodia corr :  0.343167618748
# Processing  CD - Chad
# Processed  Chad corr :  0.177072654658
# Processing  CE - Sri Lanka
# Processed  Sri Lanka corr :  0.152044875587
# Processing  CI - Chile
# Processed  Chile corr :  0.256356651438
# Processing  CJ - Cayman Islands
# Processed  Cayman Islands corr :  0.3817273243
# Processing  CM - Cameroon
# Processed  Cameroon corr :  0.310159736654
# Processing  CN - Comoros
# Processed  Comoros corr :  0.0843909736386
# Processing  CO - Colombia
# Processed  Colombia corr :  0.267868725401
# Processing  CS - Costa Rica
# Processed  Costa Rica corr :  0.174515342158
# Processing  CT - Central African Republic
# Processed  Central African Republic corr :  0.232653834407
# Processing  CU - Cuba
# Processed  Cuba corr :  0.0894124410081
# Processing  CY - Cyprus
# Processed  Cyprus corr :  0.0343006376689
# Processing  DA - Denmark
# Processed  Denmark corr :  0.167188881325
# Processing  DJ - Djibouti
# Processed  Djibouti corr :  0.181312278276
# Processing  DO - Dominica
# Processed  Dominica corr :  0.259991364307
# Processing  DR - Dominican Republic
# Processed  Dominican Republic corr :  0.00298877492694
# Processing  EC - Ecuador
# Processed  Ecuador corr :  0.302795708172
# Processing  EI - Ireland
# Processed  Ireland corr :  0.523889326306
# Processing  EK - Equatorial Guinea
# Processed  Equatorial Guinea corr :  0.176778570671
# Processing  EN - Estonia
# Processed  Estonia corr :  0.0617031933285
# Processing  ER - Eritrea
# Processed  Eritrea corr :  0.144275236284
# Processing  ES - El Salvador
# Processed  El Salvador corr :  0.1856267196
# Processing  ET - Ethiopia
# Processed  Ethiopia corr :  0.0819180175422
# Processing  FI - Finland
# Processed  Finland corr :  0.0870407590231
# Processing  FJ - Fiji
# Processed  Fiji corr :  0.00432860668809
# Processing  FP - French Polynesia
# Processed  French Polynesia corr :  0.0752816814921
# Processing  FR - France
# Processed  France corr :  0.0417297348363
# Processing  GB - Gabon
# Processed  Gabon corr :  0.0051996786175
# Processing  GG - Georgia
# Processed  Georgia corr :  0.120619201022
# Processing  GH - Ghana
# Processed  Ghana corr :  0.515615831947
# Processing  GJ - Grenada
# Processed  Grenada corr :  0.0965197080462
# Processing  GL - Greenland
# Processed  Greenland corr :  0.0307232646865
# Processing  GM - Germany
# Processed  Germany corr :  0.0155953646031
# Processing  GR - Greece
# Processed  Greece corr :  0.0367515474875
# Processing  GT - Guatemala
# Processed  Guatemala corr :  0.000893346877557
# Processing  GV - Guinea
# Processed  Guinea corr :  0.0154764769659
# Processing  GY - Guyana
# Processed  Guyana corr :  0.0419047606077
# Processing  HA - Haiti
# Processed  Haiti corr :  0.171142667589
# Processing  HO - Honduras
# Processed  Honduras corr :  0.00247136524897
# Processing  HR - Croatia
# Processed  Croatia corr :  0.000107340426215
# Processing  HU - Hungary
# Processed  Hungary corr :  0.188618521213
# Processing  IC - Iceland
# Processed  Iceland corr :  0.229942253803
# Processing  ID - Indonesia
# Processed  Indonesia corr :  0.0024463315133
# Processing  IN - India
# Processed  India corr :  0.312936362654
# Processing  IS - Israel
# Processed  Israel corr :  0.276664888269
# Processing  IT - Italy
# Processed  Italy corr :  0.0296140313916
# Processing  IZ - Iraq
# Processed  Iraq corr :  0.399550574722
# Processing  JA - Japan
# Processed  Japan corr :  0.231418433056
# Processing  JM - Jamaica
# Processed  Jamaica corr :  0.014511139829
# Processing  JO - Jordan
# Processed  Jordan corr :  0.107183544792
# Processing  KE - Kenya
# Processed  Kenya corr :  0.279146194221
# Processing  KR - Kiribati
# Processed  Kiribati corr :  4.75932394405e-05
# Processing  KU - Kuwait
# Processed  Kuwait corr :  4.02991608262e-05
# Processing  KZ - Kazakhstan
# Processed  Kazakhstan corr :  0.385218607648
# Processing  LE - Lebanon
# Processed  Lebanon corr :  0.0569454205427
# Processing  LG - Latvia
# Processed  Latvia corr :  0.205280815923
# Processing  LH - Lithuania
# Processed  Lithuania corr :  0.0988144529756
# Processing  LI - Liberia
# Processed  Liberia corr :  0.0946456565214
# Processing  LS - Liechtenstein
# Processed  Liechtenstein corr :  0.0226085185203
# Processing  LT - Lesotho
# Processed  Lesotho corr :  0.231497100261
# Processing  LU - Luxembourg
# Processed  Luxembourg corr :  0.211217789077
# Processing  LY - Libya
# Processed  Libya corr :  0.681267465327
# Processing  MA - Madagascar
# Processed  Madagascar corr :  0.215028588578
# Processing  MG - Mongolia
# Processed  Mongolia corr :  0.0125292813042
# Processing  MI - Malawi
# Processed  Malawi corr :  0.185169453757
# Processing  MJ - Montenegro
# Processed  Montenegro corr :  0.282150149062
# Processing  ML - Mali
# Processed  Mali corr :  0.727911937584
# Processing  MN - Monaco
# Processed  Monaco corr :  0.0093373251694
# Processing  MO - Morocco
# Processed  Morocco corr :  0.553867942289
# Processing  MP - Mauritius
# Processed  Mauritius corr :  0.159997513367
# Processing  MR - Mauritania
# Processed  Mauritania corr :  0.277703853104
# Processing  MT - Malta
# Processed  Malta corr :  0.0340148068047
# Processing  MU - Oman
# Processed  Oman corr :  0.0793248710333
# Processing  MV - Maldives
# Processed  Maldives corr :  0.268096841618
# Processing  MX - Mexico
# Processed  Mexico corr :  0.309879726597
# Processing  MY - Malaysia
# Processed  Malaysia corr :  0.169505695789
# Processing  MZ - Mozambique
# Processed  Mozambique corr :  0.178527308129
# Processing  NC - New Caledonia
# Processed  New Caledonia corr :  0.0835552485068
# Processing  NG - Niger
# Processed  Niger corr :  0.0448163702009
# Processing  NH - Vanuatu
# Processed  Vanuatu corr :  0.528284084752
# Processing  NI - Nigeria
# Processed  Nigeria corr :  0.0397135079019
# Processing  NL - Netherlands
# Processed  Netherlands corr :  0.033823733718
# Processing  NO - Norway
# Processed  Norway corr :  0.326887846186
# Processing  NP - Nepal
# Processed  Nepal corr :  0.352365021172
# Processing  NS - Suriname
# Processed  Suriname corr :  0.066153112052
# Processing  NU - Nicaragua
# Processed  Nicaragua corr :  0.140946181869
# Processing  NZ - New Zealand
# Processed  New Zealand corr :  0.103000339137
# Processing  PA - Paraguay
# Processed  Paraguay corr :  0.0803739268951
# Processing  PE - Peru
# Processed  Peru corr :  0.470972845416
# Processing  PK - Pakistan
# Processed  Pakistan corr :  0.0872624420383
# Processing  PL - Poland
# Processed  Poland corr :  0.37415325838
# Processing  PM - Panama
# Processed  Panama corr :  0.000231725465687
# Processing  PO - Portugal
# Processed  Portugal corr :  0.253703226538
# Processing  PP - Papua New Guinea
# Processed  Papua New Guinea corr :  0.304630708834
# Processing  PU - Guinea-Bissau
# Processed  Guinea-Bissau corr :  0.361201569268
# Processing  QA - Qatar
# Processed  Qatar corr :  0.0339311480135
# Processing  RM - Marshall Islands
# Processed  Marshall Islands corr :  0.041244309376
# Processing  RO - Romania
# Processed  Romania corr :  0.339121545976
# Processing  RP - Philippines
# Processed  Philippines corr :  0.280969747587
# Processing  RQ - Puerto Rico
# Processed  Puerto Rico corr :  0.021148439412
# Processing  RS - Russian Federation
# Processed  Russian Federation corr :  0.00174487664945
# Processing  RW - Rwanda
# Processed  Rwanda corr :  0.235707920126
# Processing  SA - Saudi Arabia
# Processed  Saudi Arabia corr :  0.225205331295
# Processing  SE - Seychelles
# Processed  Seychelles corr :  0.334797163402
# Processing  SF - South Africa
# Processed  South Africa corr :  0.302446490961
# Processing  SG - Senegal
# Processed  Senegal corr :  0.0972300935137
# Processing  SI - Slovenia
# Processed  Slovenia corr :  0.16421510444
# Processing  SL - Sierra Leone
# Processed  Sierra Leone corr :  0.0838326511418
# Processing  SN - Singapore
# Processed  Singapore corr :  0.0476640874815
# Processing  SO - Somalia
# Processed  Somalia corr :  0.00127532769033
# Processing  SP - Spain
# Processed  Spain corr :  0.0204274557937
# Processing  SU - Sudan
# Processed  Sudan corr :  0.194547174983
# Processing  SW - Sweden
# Processed  Sweden corr :  0.00268840190481
# Processing  SY - Syria
# Processed  Syria corr :  0.0948216265879
# Processing  SZ - Switzerland
# Processed  Switzerland corr :  0.288683091316
# Processing  TD - Trinidad and Tobago
# Processed  Trinidad and Tobago corr :  0.0743740862604
# Processing  TH - Thailand
# Processed  Thailand corr :  0.00211362832411
# Processing  TI - Tajikistan
# Processed  Tajikistan corr :  0.0958611531391
# Processing  TN - Tonga
# Processed  Tonga corr :  0.0194294622138
# Processing  TO - Togo
# Processed  Togo corr :  0.175541806896
# Processing  TP - Sao Tome and Principe
# Processed  Sao Tome and Principe corr :  0.00806099070936
# Processing  TS - Tunisia
# Processed  Tunisia corr :  0.573706934677
# Processing  TT - Timor-Leste
# Processed  Timor-Leste corr :  0.0635768274311
# Processing  TU - Turkey
# Processed  Turkey corr :  0.0460731646053
# Processing  TV - Tuvalu
# Processed  Tuvalu corr :  0.00456211702149
# Processing  TX - Turkmenistan
# Processed  Turkmenistan corr :  0.0587679294164
# Processing  UG - Uganda
# Processed  Uganda corr :  0.165441778284
# Processing  UP - Ukraine
# Processed  Ukraine corr :  0.82919227595
# Processing  US - United States of America
# Processed  United States of America corr :  0.264004775525
# Processing  UV - Burkina Faso
# Processed  Burkina Faso corr :  0.435778318396
# Processing  UY - Uruguay
# Processed  Uruguay corr :  0.238757111401
# Processing  UZ - Uzbekistan
# Processed  Uzbekistan corr :  0.0287265343376
# Processing  WA - Namibia
# Processed  Namibia corr :  0.0542294131008
# Processing  WS - Samoa
# Processed  Samoa corr :  0.335369924519
# Processing  WZ - Swaziland
# Processed  Swaziland corr :  0.224891249381
# Processing  ZA - Zambia
# Processed  Zambia corr :  0.0143399732269
# Processing  ZI - Zimbabwe
# Processed  Zimbabwe corr :  0.336831347619

# %% [markdown]
# ### Fetching the correlation data for the countries
# ##### this process takes ~ 3h

# %%
countries_data['Pearson Corr QuadClass1'] = np.NaN
countries_data['Pearson Corr QuadClass2'] = np.NaN
countries_data['Pearson Corr QuadClass3'] = np.NaN
countries_data['Pearson Corr QuadClass4'] = np.NaN



for i, cntr_code in enumerate(sorted(list(set(cntr_codes)))):
    pd.to_pickle(countries_data,'countries_data.pckl')
    try:
        prev_val = countries_data[countries_data['FIPS']==cntr_code]['Pearson Corr QuadClass1'].values[0]
    except:
        continue
    if str(prev_val).upper() == 'NAN':
        
        name = countries_data[countries_data['FIPS']==cntr_code]['Country'].values
        if(len(name) == 0):
            print('Processing ', cntr_code, 'NO CODE FOUND')

        print('Processing ', cntr_code, '-', name[0])

        if  len(str(name[0])) > 3:
            corr, _ = analyse_wiki_events_correlation_QuadClass(cntr_code,name[0],'20110101000000', '20171215000000');
            countries_data.ix[countries_data['FIPS']==cntr_code,'Pearson Corr QuadClass1'] = corr[0] ;
            countries_data.ix[countries_data['FIPS']==cntr_code,'Pearson Corr QuadClass2'] = corr[1] ;
            countries_data.ix[countries_data['FIPS']==cntr_code,'Pearson Corr QuadClass3'] = corr[2] ;
            countries_data.ix[countries_data['FIPS']==cntr_code,'Pearson Corr QuadClass4'] = corr[3] ;
            print('Processed ', name[0] , 'corr : ', corr)

        else:
            print('Processed ', cntr_code , ' NaN CODE ')
    else:
        print(cntr_code,'Already processed.')
# Out:
# Processing  AA - Aruba
# [ 0.00263424  0.01465992 -0.02288378  0.0155933 ]
# Processed  Aruba corr :  [ 0.00263424  0.01465992 -0.02288378  0.0155933 ]
# Processing  AC - Antigua and Barbuda
# [ 0.23580558  0.27464914  0.14103313  0.25541004]
# Processed  Antigua and Barbuda corr :  [ 0.23580558  0.27464914  0.14103313  0.25541004]
# Processing  AE - United Arab Emirates
# [ 0.04952583 -0.00053588 -0.00732353  0.00061132]
# Processed  United Arab Emirates corr :  [ 0.04952583 -0.00053588 -0.00732353  0.00061132]
# Processing  AF - Afghanistan
# [ 0.07250873  0.1873494   0.06244916  0.26092188]
# Processed  Afghanistan corr :  [ 0.07250873  0.1873494   0.06244916  0.26092188]
# Processing  AG - Algeria
# [ 0.4971767   0.52476397  0.5496912   0.51797644]
# Processed  Algeria corr :  [ 0.4971767   0.52476397  0.5496912   0.51797644]
# Processing  AJ - Azerbaijan
# [ 0.15340197  0.1522232   0.06912243  0.11087037]
# Processed  Azerbaijan corr :  [ 0.15340197  0.1522232   0.06912243  0.11087037]
# Processing  AL - Albania
# [ 0.03878854  0.07891775  0.06049697  0.01172239]
# Processed  Albania corr :  [ 0.03878854  0.07891775  0.06049697  0.01172239]
# Processing  AM - Armenia
# [-0.00985835 -0.00049483  0.02611052  0.07882055]
# Processed  Armenia corr :  [-0.00985835 -0.00049483  0.02611052  0.07882055]
# Processing  AN - Andorra
# [ 0.00033623 -0.09149653 -0.18934585 -0.14879719]
# Processed  Andorra corr :  [ 0.00033623 -0.09149653 -0.18934585 -0.14879719]
# Processing  AO - Angola
# [ 0.28525691  0.02381046  0.00560825  0.00374105]
# Processed  Angola corr :  [ 0.28525691  0.02381046  0.00560825  0.00374105]
# Processing  AR - Argentina
# [-0.00070635 -0.10842538  0.03487292 -0.00803142]
# Processed  Argentina corr :  [-0.00070635 -0.10842538  0.03487292 -0.00803142]
# Processing  AS - Australia
# [-0.21944088 -0.23636827 -0.21113296 -0.16274658]
# Processed  Australia corr :  [-0.21944088 -0.23636827 -0.21113296 -0.16274658]
# Processing  AU - Austria
# [-0.20282865 -0.1774625  -0.14652865 -0.09606705]
# Processed  Austria corr :  [-0.20282865 -0.1774625  -0.14652865 -0.09606705]
# Processing  AV - nan
# Processed  AV  NaN CODE
# Processing  AY - nan
# Processed  AY  NaN CODE
# Processing  BA - Bahrain
# [ 0.0735152   0.09678571  0.1329922   0.1480623 ]
# Processed  Bahrain corr :  [ 0.0735152   0.09678571  0.1329922   0.1480623 ]
# Processing  BB - Barbados
# [-0.1457139  -0.18125177 -0.11362521 -0.07862823]
# Processed  Barbados corr :  [-0.1457139  -0.18125177 -0.11362521 -0.07862823]
# Processing  BC - Botswana
# [-0.13773547 -0.21232537 -0.09214998 -0.04532253]
# Processed  Botswana corr :  [-0.13773547 -0.21232537 -0.09214998 -0.04532253]
# Processing  BD - Bermuda
# [ 0.13008857  0.22041255  0.21510347  0.27640311]
# Processed  Bermuda corr :  [ 0.13008857  0.22041255  0.21510347  0.27640311]
# Processing  BE - Belgium
# [-0.15873993 -0.06494162 -0.01632781  0.03396066]
# Processed  Belgium corr :  [-0.15873993 -0.06494162 -0.01632781  0.03396066]
# Processing  BG - Bangladesh
# [-0.39931899 -0.39040048 -0.3058322  -0.29351766]
# Processed  Bangladesh corr :  [-0.39931899 -0.39040048 -0.3058322  -0.29351766]
# Processing  BH - Belize
# [-0.34833836 -0.30790615 -0.33609125 -0.28132702]
# Processed  Belize corr :  [-0.34833836 -0.30790615 -0.33609125 -0.28132702]
# Processing  BK - Bosnia and Herzegovina
# [-0.00484102  0.02174381  0.00170711  0.00836347]
# Processed  Bosnia and Herzegovina corr :  [-0.00484102  0.02174381  0.00170711  0.00836347]
# Processing  BL - Bolivia
# [ -5.61940662e-02  -3.66168864e-02   1.11432784e-04  -1.32551191e-01]
# Processed  Bolivia corr :  [ -5.61940662e-02  -3.66168864e-02   1.11432784e-04  -1.32551191e-01]
# Processing  BM - Myanmar
# [ 0.02755209  0.04393175 -0.04700824 -0.07735026]
# Processed  Myanmar corr :  [ 0.02755209  0.04393175 -0.04700824 -0.07735026]
# Processing  BN - Benin
# [-0.21366973 -0.16038937 -0.16761423 -0.07409947]
# Processed  Benin corr :  [-0.21366973 -0.16038937 -0.16761423 -0.07409947]
# Processing  BO - Belarus
# [ -5.94441092e-02  -6.61929729e-05   2.89550690e-02   2.09759654e-02]
# Processed  Belarus corr :  [ -5.94441092e-02  -6.61929729e-05   2.89550690e-02   2.09759654e-02]
# Processing  BP - Solomon Islands
# [-0.01390651  0.07435556 -0.04219846  0.21551536]
# Processed  Solomon Islands corr :  [-0.01390651  0.07435556 -0.04219846  0.21551536]
# Processing  BR - Brazil
# [-0.14559205 -0.15360056 -0.10454979 -0.16979061]
# Processed  Brazil corr :  [-0.14559205 -0.15360056 -0.10454979 -0.16979061]
# Processing  BT - Bhutan
# [-0.15191808 -0.1519679  -0.16208471 -0.23248977]
# Processed  Bhutan corr :  [-0.15191808 -0.1519679  -0.16208471 -0.23248977]
# Processing  BU - Bulgaria
# [-0.11241107 -0.10847665 -0.00691404 -0.0054235 ]
# Processed  Bulgaria corr :  [-0.11241107 -0.10847665 -0.00691404 -0.0054235 ]
# Processing  BX - Brunei Darussalam
# [-0.0036104  -0.03792764 -0.04722306 -0.06449246]
# Processed  Brunei Darussalam corr :  [-0.0036104  -0.03792764 -0.04722306 -0.06449246]
# Processing  BY - Burundi
# [ 0.61680541  0.5804994   0.6120066   0.54326415]
# Processed  Burundi corr :  [ 0.61680541  0.5804994   0.6120066   0.54326415]
# Processing  CA - Canada
# [ 0.09402165  0.08682269  0.12270143  0.13299032]
# Processed  Canada corr :  [ 0.09402165  0.08682269  0.12270143  0.13299032]
# Processing  CB - Cambodia
# [-0.37126675 -0.379297   -0.28016179 -0.1326552 ]
# Processed  Cambodia corr :  [-0.37126675 -0.379297   -0.28016179 -0.1326552 ]
# Processing  CD - Chad
# [-0.13038175 -0.17532559 -0.18806868 -0.20430338]
# Processed  Chad corr :  [-0.13038175 -0.17532559 -0.18806868 -0.20430338]
# Processing  CE - Sri Lanka
# [-0.1295628  -0.1730537  -0.14384525 -0.17427567]
# Processed  Sri Lanka corr :  [-0.1295628  -0.1730537  -0.14384525 -0.17427567]
# Processing  CH - China
# [-0.30280769 -0.27541331 -0.25789446 -0.28716443]
# Processed  China corr :  [-0.30280769 -0.27541331 -0.25789446 -0.28716443]
# Processing  CI - Chile
# [-0.21383161 -0.34231386 -0.25127079 -0.26238158]
# Processed  Chile corr :  [-0.21383161 -0.34231386 -0.25127079 -0.26238158]
# Processing  CJ - Cayman Islands
# [-0.38961716 -0.37589586 -0.2769301  -0.16911448]
# Processed  Cayman Islands corr :  [-0.38961716 -0.37589586 -0.2769301  -0.16911448]
# Processing  CM - Cameroon
# [-0.27498774 -0.2469242  -0.32776211 -0.3327491 ]
# Processed  Cameroon corr :  [-0.27498774 -0.2469242  -0.32776211 -0.3327491 ]
# Processing  CN - Comoros
# [-0.02646653 -0.03020421 -0.03952328 -0.15881716]
# Processed  Comoros corr :  [-0.02646653 -0.03020421 -0.03952328 -0.15881716]
# Processing  CO - Colombia
# [-0.27273909 -0.16286315 -0.24778129 -0.22063579]
# Processed  Colombia corr :  [-0.27273909 -0.16286315 -0.24778129 -0.22063579]
# Processing  CS - Costa Rica
# [ -2.19191380e-01  -1.21522770e-01  -5.33679478e-05  -9.49831180e-02]
# Processed  Costa Rica corr :  [ -2.19191380e-01  -1.21522770e-01  -5.33679478e-05  -9.49831180e-02]
# Processing  CT - Central African Republic
# [ 0.1810272   0.27815323  0.30060782  0.23522147]
# Processed  Central African Republic corr :  [ 0.1810272   0.27815323  0.30060782  0.23522147]
# Processing  CU - Cuba
# [ 0.07772026  0.12530723  0.05469943  0.13696894]
# Processed  Cuba corr :  [ 0.07772026  0.12530723  0.05469943  0.13696894]
# Processing  CY - Cyprus
# [ 0.00915106  0.10573822  0.18215645 -0.00101637]
# Processed  Cyprus corr :  [ 0.00915106  0.10573822  0.18215645 -0.00101637]
# Processing  DA - Denmark
# [-0.15781259 -0.15709816 -0.16250153 -0.15540815]
# Processed  Denmark corr :  [-0.15781259 -0.15709816 -0.16250153 -0.15540815]
# Processing  DJ - Djibouti
# [ -2.02504179e-01  -1.49758846e-01  -1.06228969e-04  -1.37658696e-01]
# Processed  Djibouti corr :  [ -2.02504179e-01  -1.49758846e-01  -1.06228969e-04  -1.37658696e-01]
# Processing  DO - Dominica
# [ 0.24726943  0.26664421  0.19468428  0.2582694 ]
# Processed  Dominica corr :  [ 0.24726943  0.26664421  0.19468428  0.2582694 ]
# Processing  DR - Dominican Republic
# [  1.24429893e-04  -7.01959155e-07   8.03598187e-02   3.33127462e-03]
# Processed  Dominican Republic corr :  [  1.24429893e-04  -7.01959155e-07   8.03598187e-02   3.33127462e-03]
# Processing  EC - Ecuador
# [ 0.204495    0.38179994  0.41399841  0.38504752]
# Processed  Ecuador corr :  [ 0.204495    0.38179994  0.41399841  0.38504752]
# Processing  EI - Ireland
# [-0.51987648 -0.53732835 -0.51206598 -0.50761548]
# Processed  Ireland corr :  [-0.51987648 -0.53732835 -0.51206598 -0.50761548]
# Processing  EK - Equatorial Guinea
# [-0.19317129 -0.01523386 -0.11253425  0.00430993]
# Processed  Equatorial Guinea corr :  [-0.19317129 -0.01523386 -0.11253425  0.00430993]
# Processing  EN - Estonia
# [ 0.06615634  0.08644598  0.09215296 -0.0027769 ]
# Processed  Estonia corr :  [ 0.06615634  0.08644598  0.09215296 -0.0027769 ]
# Processing  ER - Eritrea
# [ 0.10190961  0.07961875  0.18703867  0.20077372]
# Processed  Eritrea corr :  [ 0.10190961  0.07961875  0.18703867  0.20077372]
# Processing  ES - El Salvador
# [-0.11344651 -0.26617261 -0.19604026 -0.27269753]
# Processed  El Salvador corr :  [-0.11344651 -0.26617261 -0.19604026 -0.27269753]
# Processing  ET - Ethiopia
# [ 0.06870142  0.09257657  0.08140713  0.08562817]
# Processed  Ethiopia corr :  [ 0.06870142  0.09257657  0.08140713  0.08562817]
# Processing  EZ - Czech Republic
# [ 0.06455809  0.00023994  0.08291628  0.0003863 ]
# Processed  Czech Republic corr :  [ 0.06455809  0.00023994  0.08291628  0.0003863 ]
# Processing  FI - Finland
# [-0.06191077 -0.17086345 -0.14076717 -0.0389415 ]
# Processed  Finland corr :  [-0.06191077 -0.17086345 -0.14076717 -0.0389415 ]
# Processing  FJ - Fiji
# [-0.00331449  0.06122773  0.02520651  0.12012769]
# Processed  Fiji corr :  [-0.00331449  0.06122773  0.02520651  0.12012769]
# Processing  FP - French Polynesia
# [ 0.05945619  0.0643152   0.03545453  0.18504588]
# Processed  French Polynesia corr :  [ 0.05945619  0.0643152   0.03545453  0.18504588]
# Processing  FR - France
# [ 0.0199197   0.06561761  0.09383165  0.0618583 ]
# Processed  France corr :  [ 0.0199197   0.06561761  0.09383165  0.0618583 ]
# Processing  GB - Gabon
# [ -3.64385916e-06  -1.90002763e-02  -1.61240747e-02  -4.12342006e-02]
# Processed  Gabon corr :  [ -3.64385916e-06  -1.90002763e-02  -1.61240747e-02  -4.12342006e-02]
# Processing  GG - Georgia
# [ 0.12444637  0.10813917  0.08183968  0.11844875]
# Processed  Georgia corr :  [ 0.12444637  0.10813917  0.08183968  0.11844875]
# Processing  GH - Ghana
# [-0.50945181 -0.50284989 -0.5237372  -0.49971217]
# Processed  Ghana corr :  [-0.50945181 -0.50284989 -0.5237372  -0.49971217]
# Processing  GJ - Grenada
# [ 0.09311325  0.08246872  0.10748723  0.0974922 ]
# Processed  Grenada corr :  [ 0.09311325  0.08246872  0.10748723  0.0974922 ]
# Processing  GL - Greenland
# [-0.05357971 -0.01792215 -0.08775693  0.02660587]
# Processed  Greenland corr :  [-0.05357971 -0.01792215 -0.08775693  0.02660587]
# Processing  GM - Germany
# [-0.01447885 -0.02699011 -0.01164616 -0.01197334]
# Processed  Germany corr :  [-0.01447885 -0.02699011 -0.01164616 -0.01197334]
# Processing  GR - Greece
# [ 0.0349017   0.03209637  0.13021746 -0.02909441]
# Processed  Greece corr :  [ 0.0349017   0.03209637  0.13021746 -0.02909441]
# Processing  GT - Guatemala
# [-0.01148079  0.01151422  0.13327587  0.00358165]
# Processed  Guatemala corr :  [-0.01148079  0.01151422  0.13327587  0.00358165]
# Processing  GV - Guinea
# [ 0.01321184  0.01809417  0.00401504  0.02665556]
# Processed  Guinea corr :  [ 0.01321184  0.01809417  0.00401504  0.02665556]
# Processing  GY - Guyana
# [-0.0399143  -0.06402425 -0.0084504  -0.07946527]
# Processed  Guyana corr :  [-0.0399143  -0.06402425 -0.0084504  -0.07946527]
# Processing  HA - Haiti
# [ 0.18539595  0.09086531  0.19400118  0.13833895]
# Processed  Haiti corr :  [ 0.18539595  0.09086531  0.19400118  0.13833895]
# Processing  HO - Honduras
# [  1.69927510e-03  -3.80707427e-02   5.97311993e-05  -2.93072300e-02]
# Processed  Honduras corr :  [  1.69927510e-03  -3.80707427e-02   5.97311993e-05  -2.93072300e-02]
# Processing  HR - Croatia
# [ -6.53592401e-04   3.78491723e-04  -3.56977185e-05   2.69216220e-03]
# Processed  Croatia corr :  [ -6.53592401e-04   3.78491723e-04  -3.56977185e-05   2.69216220e-03]
# Processing  HU - Hungary
# [-0.20493922 -0.14998817 -0.14962983 -0.16865851]
# Processed  Hungary corr :  [-0.20493922 -0.14998817 -0.14962983 -0.16865851]
# Processing  IC - Iceland
# [-0.22910305 -0.197841   -0.16968926 -0.22107699]
# Processed  Iceland corr :  [-0.22910305 -0.197841   -0.16968926 -0.22107699]
# Processing  ID - Indonesia
# [-0.008383   -0.02044082  0.00011375  0.01918736]
# Processed  Indonesia corr :  [-0.008383   -0.02044082  0.00011375  0.01918736]
# Processing  IN - India
# [-0.3112722  -0.31358147 -0.30863119 -0.30824209]
# Processed  India corr :  [-0.3112722  -0.31358147 -0.30863119 -0.30824209]
# Processing  IR - Iran
# [ 0.14679504  0.11795992  0.03181405  0.00081188]
# Processed  Iran corr :  [ 0.14679504  0.11795992  0.03181405  0.00081188]
# Processing  IS - Israel
# [ 0.22812022  0.32404913  0.32722222  0.2646953 ]
# Processed  Israel corr :  [ 0.22812022  0.32404913  0.32722222  0.2646953 ]
# Processing  IT - Italy
# [ 0.02924574  0.00501356  0.06568268  0.02361407]
# Processed  Italy corr :  [ 0.02924574  0.00501356  0.06568268  0.02361407]
# Processing  IZ - Iraq
# [-0.3712187  -0.39468845 -0.36921377 -0.44767703]
# Processed  Iraq corr :  [-0.3712187  -0.39468845 -0.36921377 -0.44767703]
# Processing  JA - Japan
# [ 0.2222026   0.33798353  0.12906572  0.16043717]
# Processed  Japan corr :  [ 0.2222026   0.33798353  0.12906572  0.16043717]
# Processing  JM - Jamaica
# [ 0.0114746   0.00440397  0.05535045  0.01377345]
# Processed  Jamaica corr :  [ 0.0114746   0.00440397  0.05535045  0.01377345]
# Processing  JO - Jordan
# [ 0.13270471  0.10422442  0.04059694  0.03809439]
# Processed  Jordan corr :  [ 0.13270471  0.10422442  0.04059694  0.03809439]
# Processing  KE - Kenya
# [-0.30872763 -0.27810946 -0.30832152 -0.06809496]
# Processed  Kenya corr :  [-0.30872763 -0.27810946 -0.30832152 -0.06809496]
# Processing  KR - Kiribati
# [ 0.00325255 -0.04141437 -0.11110592  0.03252789]
# Processed  Kiribati corr :  [ 0.00325255 -0.04141437 -0.11110592  0.03252789]
# Processing  KS - South Korea
# [ 0.27326918  0.23684826  0.31370496  0.2802549 ]
# Processed  South Korea corr :  [ 0.27326918  0.23684826  0.31370496  0.2802549 ]
# Processing  KU - Kuwait
# [-0.00106489  0.05975342 -0.11458208  0.03027946]
# Processed  Kuwait corr :  [-0.00106489  0.05975342 -0.11458208  0.03027946]
# Processing  KZ - Kazakhstan
# [-0.33957232 -0.37962344 -0.46087511 -0.41354201]
# Processed  Kazakhstan corr :  [-0.33957232 -0.37962344 -0.46087511 -0.41354201]
# Processing  LE - Lebanon
# [ 0.07364645 -0.01700481  0.23804729  0.00107934]
# Processed  Lebanon corr :  [ 0.07364645 -0.01700481  0.23804729  0.00107934]
# Processing  LG - Latvia
# [-0.18746374 -0.1560746  -0.22899427 -0.25527034]
# Processed  Latvia corr :  [-0.18746374 -0.1560746  -0.22899427 -0.25527034]
# Processing  LH - Lithuania
# [-0.09866027 -0.06432251 -0.11773765 -0.0189683 ]
# Processed  Lithuania corr :  [-0.09866027 -0.06432251 -0.11773765 -0.0189683 ]
# Processing  LI - Liberia
# [ 0.0913612   0.12200514  0.08731998  0.06190273]
# Processed  Liberia corr :  [ 0.0913612   0.12200514  0.08731998  0.06190273]
# Processing  LO - Slovakia
# [ 0.15468101  0.00224507  0.07507428  0.0058726 ]
# Processed  Slovakia corr :  [ 0.15468101  0.00224507  0.07507428  0.0058726 ]
# Processing  LS - Liechtenstein
# [-0.03357587 -0.03285596  0.03211887 -0.03961463]
# Processed  Liechtenstein corr :  [-0.03357587 -0.03285596  0.03211887 -0.03961463]
# Processing  LT - Lesotho
# [-0.24021893 -0.2268911  -0.18802588 -0.18148136]
# Processed  Lesotho corr :  [-0.24021893 -0.2268911  -0.18802588 -0.18148136]
# Processing  LU - Luxembourg
# [-0.18026056 -0.25554659 -0.2697532  -0.27124681]
# Processed  Luxembourg corr :  [-0.18026056 -0.25554659 -0.2697532  -0.27124681]
# Processing  LY - Libya
# [ 0.67342812  0.67792834  0.7262268   0.66115042]
# Processed  Libya corr :  [ 0.67342812  0.67792834  0.7262268   0.66115042]
# Processing  MA - Madagascar
# [ 0.21493875  0.03797748  0.17275989  0.23873963]
# Processed  Madagascar corr :  [ 0.21493875  0.03797748  0.17275989  0.23873963]
# Processing  MG - Mongolia
# [ 0.0003348   0.20808932 -0.01854653  0.21243027]
# Processed  Mongolia corr :  [ 0.0003348   0.20808932 -0.01854653  0.21243027]
# Processing  MI - Malawi
# [-0.18129376 -0.24208998 -0.10087402 -0.18240647]
# Processed  Malawi corr :  [-0.18129376 -0.24208998 -0.10087402 -0.18240647]
# Processing  MJ - Montenegro
# [ 0.27283771  0.36182627  0.25064109  0.20237752]
# Processed  Montenegro corr :  [ 0.27283771  0.36182627  0.25064109  0.20237752]
# Processing  ML - Mali
# [ 0.73595844  0.72894476  0.73302685  0.68257864]
# Processed  Mali corr :  [ 0.73595844  0.72894476  0.73302685  0.68257864]
# Processing  MN - Monaco
# [-0.00833967 -0.02134985 -0.0006723  -0.01726665]
# Processed  Monaco corr :  [-0.00833967 -0.02134985 -0.0006723  -0.01726665]
# Processing  MO - Morocco
# [-0.53867252 -0.50986887 -0.4190237  -0.51988716]
# Processed  Morocco corr :  [-0.53867252 -0.50986887 -0.4190237  -0.51988716]
# Processing  MP - Mauritius
# [-0.17037213 -0.08044107 -0.11493247 -0.05663029]
# Processed  Mauritius corr :  [-0.17037213 -0.08044107 -0.11493247 -0.05663029]
# Processing  MR - Mauritania
# [ 0.25389482  0.31775454  0.20988949  0.36356617]
# Processed  Mauritania corr :  [ 0.25389482  0.31775454  0.20988949  0.36356617]
# Processing  MT - Malta
# [ 0.02775499  0.06692454  0.00976494  0.05030192]
# Processed  Malta corr :  [ 0.02775499  0.06692454  0.00976494  0.05030192]
# Processing  MU - Oman
# [  3.91893438e-02  -8.50145616e-05   2.90917307e-01   1.97017989e-01]
# Processed  Oman corr :  [  3.91893438e-02  -8.50145616e-05   2.90917307e-01   1.97017989e-01]
# Processing  MV - Maldives
# [ 0.22590819  0.35038445  0.35556704  0.13229259]
# Processed  Maldives corr :  [ 0.22590819  0.35038445  0.35556704  0.13229259]
# Processing  MX - Mexico
# [-0.31538406 -0.34549193 -0.29571349 -0.19321868]
# Processed  Mexico corr :  [-0.31538406 -0.34549193 -0.29571349 -0.19321868]
# Processing  MY - Malaysia
# [-0.15268084 -0.14987158 -0.18392814 -0.19215116]
# Processed  Malaysia corr :  [-0.15268084 -0.14987158 -0.18392814 -0.19215116]
# Processing  MZ - Mozambique
# [-0.19763039 -0.13390871 -0.14135609 -0.05270996]
# Processed  Mozambique corr :  [-0.19763039 -0.13390871 -0.14135609 -0.05270996]
# Processing  NC - New Caledonia
# [-0.04878939 -0.12022023 -0.16810262 -0.14888475]
# Processed  New Caledonia corr :  [-0.04878939 -0.12022023 -0.16810262 -0.14888475]
# Processing  NG - Niger
# [-0.05368894 -0.06784352 -0.04254135 -0.01620394]
# Processed  Niger corr :  [-0.05368894 -0.06784352 -0.04254135 -0.01620394]
# Processing  NH - Vanuatu
# [ 0.5198343   0.57209608  0.3436387   0.31486675]
# Processed  Vanuatu corr :  [ 0.5198343   0.57209608  0.3436387   0.31486675]
# Processing  NI - Nigeria
# [-0.05638237 -0.04187318 -0.01597519 -0.00709662]
# Processed  Nigeria corr :  [-0.05638237 -0.04187318 -0.01597519 -0.00709662]
# Processing  NL - Netherlands
# [-0.00855049 -0.08020453 -0.10790544 -0.08597933]
# Processed  Netherlands corr :  [-0.00855049 -0.08020453 -0.10790544 -0.08597933]
# Processing  NO - Norway
# [ 0.27160356  0.21693962  0.41050771  0.42532629]
# Processed  Norway corr :  [ 0.27160356  0.21693962  0.41050771  0.42532629]
# Processing  NP - Nepal
# [ 0.34092747  0.40275696  0.16548321  0.249698  ]
# Processed  Nepal corr :  [ 0.34092747  0.40275696  0.16548321  0.249698  ]
# Processing  NS - Suriname
# [ 0.08900169 -0.02138921  0.10081299  0.00065235]
# Processed  Suriname corr :  [ 0.08900169 -0.02138921  0.10081299  0.00065235]
# Processing  NU - Nicaragua
# [-0.15233151 -0.15303187 -0.01508492 -0.06665171]
# Processed  Nicaragua corr :  [-0.15233151 -0.15303187 -0.01508492 -0.06665171]
# Processing  NZ - New Zealand
# [-0.09162864 -0.06225033 -0.17382905 -0.13857556]
# Processed  New Zealand corr :  [-0.09162864 -0.06225033 -0.17382905 -0.13857556]
# Processing  PA - Paraguay
# [-0.06904651 -0.26458977 -0.01640583 -0.05543689]
# Processed  Paraguay corr :  [-0.06904651 -0.26458977 -0.01640583 -0.05543689]
# Processing  PE - Peru
# [-0.43793142 -0.51998149 -0.43304702 -0.46908792]
# Processed  Peru corr :  [-0.43793142 -0.51998149 -0.43304702 -0.46908792]
# Processing  PK - Pakistan
# [-0.05997307 -0.09157926 -0.09466167 -0.12998533]
# Processed  Pakistan corr :  [-0.05997307 -0.09157926 -0.09466167 -0.12998533]
# Processing  PL - Poland
# [ 0.37114946  0.34071381  0.31315488  0.39797897]
# Processed  Poland corr :  [ 0.37114946  0.34071381  0.31315488  0.39797897]
# Processing  PM - Panama
# [ 0.00013555 -0.00075468 -0.00201672 -0.01138882]
# Processed  Panama corr :  [ 0.00013555 -0.00075468 -0.00201672 -0.01138882]
# Processing  PO - Portugal
# [-0.25054487 -0.26139232 -0.13639809 -0.22779376]
# Processed  Portugal corr :  [-0.25054487 -0.26139232 -0.13639809 -0.22779376]
# Processing  PP - Papua New Guinea
# [-0.30261472 -0.21248009 -0.3073777  -0.25056632]
# Processed  Papua New Guinea corr :  [-0.30261472 -0.21248009 -0.3073777  -0.25056632]
# Processing  PU - Guinea-Bissau
# [ 0.35471254  0.32794941  0.27326808  0.3666147 ]
# Processed  Guinea-Bissau corr :  [ 0.35471254  0.32794941  0.27326808  0.3666147 ]
# Processing  QA - Qatar
# [ 0.04786957  0.01327978  0.00880951  0.04460509]
# Processed  Qatar corr :  [ 0.04786957  0.01327978  0.00880951  0.04460509]
# Processing  RM - Marshall Islands
# [ 0.03816201  0.04628806  0.00035378  0.0478563 ]
# Processed  Marshall Islands corr :  [ 0.03816201  0.04628806  0.00035378  0.0478563 ]
# Processing  RO - Romania
# [-0.34952463 -0.2683104  -0.23648959 -0.34959367]
# Processed  Romania corr :  [-0.34952463 -0.2683104  -0.23648959 -0.34959367]
# Processing  RP - Philippines
# [ 0.28572201  0.29337037  0.24183209  0.24348176]
# Processed  Philippines corr :  [ 0.28572201  0.29337037  0.24183209  0.24348176]
# Processing  RQ - Puerto Rico
# [-0.03878055 -0.01316812 -0.01011882  0.04816207]
# Processed  Puerto Rico corr :  [-0.03878055 -0.01316812 -0.01011882  0.04816207]
# Processing  RS - Russian Federation
# [-0.00874094 -0.00423357  0.00175657  0.00691551]
# Processed  Russian Federation corr :  [-0.00874094 -0.00423357  0.00175657  0.00691551]
# Processing  RW - Rwanda
# [-0.24708339 -0.24054054 -0.21500423 -0.07262281]
# Processed  Rwanda corr :  [-0.24708339 -0.24054054 -0.21500423 -0.07262281]
# Processing  SA - Saudi Arabia
# [-0.22481775 -0.22595133 -0.18199643 -0.21567838]
# Processed  Saudi Arabia corr :  [-0.22481775 -0.22595133 -0.18199643 -0.21567838]
# Processing  SE - Seychelles
# [ 0.34133589  0.31732968  0.31166159  0.32266363]
# Processed  Seychelles corr :  [ 0.34133589  0.31732968  0.31166159  0.32266363]
# Processing  SF - South Africa
# [-0.28546534 -0.32689091 -0.32298609 -0.28254693]
# Processed  South Africa corr :  [-0.28546534 -0.32689091 -0.32298609 -0.28254693]
# Processing  SG - Senegal
# [ 0.06762954  0.06518443  0.21232409  0.11150743]
# Processed  Senegal corr :  [ 0.06762954  0.06518443  0.21232409  0.11150743]
# Processing  SI - Slovenia
# [-0.17461063 -0.20386044 -0.1425923  -0.0588198 ]
# Processed  Slovenia corr :  [-0.17461063 -0.20386044 -0.1425923  -0.0588198 ]
# Processing  SL - Sierra Leone
# [ 0.06438155  0.05036153  0.12499234  0.18098401]
# Processed  Sierra Leone corr :  [ 0.06438155  0.05036153  0.12499234  0.18098401]
# Processing  SN - Singapore
# [-0.05262927 -0.0324651  -0.00257689 -0.10230536]
# Processed  Singapore corr :  [-0.05262927 -0.0324651  -0.00257689 -0.10230536]
# Processing  SO - Somalia
# [-0.00669727  0.01059592 -0.00259394  0.06260419]
# Processed  Somalia corr :  [-0.00669727  0.01059592 -0.00259394  0.06260419]
# Processing  SP - Spain
# [-0.05957306 -0.10177491  0.0668272  -0.00087381]
# Processed  Spain corr :  [-0.05957306 -0.10177491  0.0668272  -0.00087381]
# Processing  SU - Sudan
# [ 0.22949086  0.07796137  0.1794117   0.11006155]
# Processed  Sudan corr :  [ 0.22949086  0.07796137  0.1794117   0.11006155]
# Processing  SW - Sweden
# [-0.00531416  0.00314423  0.07289372  0.07648285]
# Processed  Sweden corr :  [-0.00531416  0.00314423  0.07289372  0.07648285]
# Processing  SY - Syria
# [-0.12354987 -0.19679109  0.02911617 -0.13261648]
# Processed  Syria corr :  [-0.12354987 -0.19679109  0.02911617 -0.13261648]
# Processing  SZ - Switzerland
# [-0.27209583 -0.34500891 -0.26469806 -0.30019913]
# Processed  Switzerland corr :  [-0.27209583 -0.34500891 -0.26469806 -0.30019913]
# Processing  TD - Trinidad and Tobago
# [ 0.0536363   0.11121458  0.0577275   0.14838967]
# Processed  Trinidad and Tobago corr :  [ 0.0536363   0.11121458  0.0577275   0.14838967]
# Processing  TH - Thailand
# [-0.03166422 -0.00011716  0.07356125  0.01991179]
# Processed  Thailand corr :  [-0.03166422 -0.00011716  0.07356125  0.01991179]
# Processing  TI - Tajikistan
# [ 0.09354686  0.03647115  0.06138996  0.07929782]
# Processed  Tajikistan corr :  [ 0.09354686  0.03647115  0.06138996  0.07929782]
# Processing  TN - Tonga
# [ 0.02587706 -0.00041569  0.01223866  0.01962344]
# Processed  Tonga corr :  [ 0.02587706 -0.00041569  0.01223866  0.01962344]
# Processing  TO - Togo
# [-0.19503576 -0.06413181 -0.12223178 -0.08818494]
# Processed  Togo corr :  [-0.19503576 -0.06413181 -0.12223178 -0.08818494]
# Processing  TP - Sao Tome and Principe
# [ 0.01202341  0.08274156 -0.00362889 -0.01439373]
# Processed  Sao Tome and Principe corr :  [ 0.01202341  0.08274156 -0.00362889 -0.01439373]
# Processing  TS - Tunisia
# [ 0.5431609   0.584162    0.66091514  0.44934258]
# Processed  Tunisia corr :  [ 0.5431609   0.584162    0.66091514  0.44934258]
# Processing  TT - Timor-Leste
# [-0.06414697 -0.02735459  0.0009805  -0.08916316]
# Processed  Timor-Leste corr :  [-0.06414697 -0.02735459  0.0009805  -0.08916316]
# Processing  TU - Turkey
# [-0.06038838 -0.05041926 -0.02621635 -0.02701476]
# Processed  Turkey corr :  [-0.06038838 -0.05041926 -0.02621635 -0.02701476]
# Processing  TV - Tuvalu
# [-0.01980041  0.06744026 -0.01670348 -0.00463323]
# Processed  Tuvalu corr :  [-0.01980041  0.06744026 -0.01670348 -0.00463323]
# Processing  TX - Turkmenistan
# [-0.07544349  0.00049526 -0.00135244 -0.03058747]
# Processed  Turkmenistan corr :  [-0.07544349  0.00049526 -0.00135244 -0.03058747]
# Processing  UG - Uganda
# [-0.20201086 -0.1855492  -0.02908467 -0.08389769]
# Processed  Uganda corr :  [-0.20201086 -0.1855492  -0.02908467 -0.08389769]
# Processing  UK - United Kingdom
# [-0.16261196 -0.17342507 -0.1531311  -0.15483787]
# Processed  United Kingdom corr :  [-0.16261196 -0.17342507 -0.1531311  -0.15483787]
# Processing  UP - Ukraine
# [ 0.8381807   0.78445942  0.86506374  0.74303956]
# Processed  Ukraine corr :  [ 0.8381807   0.78445942  0.86506374  0.74303956]
# Processing  US - United States of America
# [ 0.26678865  0.26239707  0.29999634  0.20778908]
# Processed  United States of America corr :  [ 0.26678865  0.26239707  0.29999634  0.20778908]
# Processing  UV - Burkina Faso
# [ 0.45524083  0.46549975  0.63051996  0.26068036]
# Processed  Burkina Faso corr :  [ 0.45524083  0.46549975  0.63051996  0.26068036]
# Processing  UY - Uruguay
# [-0.23806665 -0.19341939 -0.06709892 -0.1700898 ]
# Processed  Uruguay corr :  [-0.23806665 -0.19341939 -0.06709892 -0.1700898 ]
# Processing  UZ - Uzbekistan
# [-0.08449985  0.00527801  0.02317688  0.08816912]
# Processed  Uzbekistan corr :  [-0.08449985  0.00527801  0.02317688  0.08816912]
# Processing  VE - Venezuela
# [ 0.06888946  0.06703533  0.31323735  0.2689555 ]
# Processed  Venezuela corr :  [ 0.06888946  0.06703533  0.31323735  0.2689555 ]
# Processing  WA - Namibia
# [-0.04772111 -0.045814   -0.0278952  -0.12233756]
# Processed  Namibia corr :  [-0.04772111 -0.045814   -0.0278952  -0.12233756]
# Processing  WS - Samoa
# [-0.32957315 -0.33195039 -0.34963205 -0.27971382]
# Processed  Samoa corr :  [-0.32957315 -0.33195039 -0.34963205 -0.27971382]
# Processing  WZ - Swaziland
# [-0.29309167 -0.14053013 -0.04507315 -0.06671113]
# Processed  Swaziland corr :  [-0.29309167 -0.14053013 -0.04507315 -0.06671113]
# Processing  ZA - Zambia
# [-0.00385089 -0.07772509  0.00041936 -0.15630595]
# Processed  Zambia corr :  [-0.00385089 -0.07772509  0.00041936 -0.15630595]
# Processing  ZI - Zimbabwe
# [ 0.34006291  0.34137561  0.30808534  0.32242223]
# Processed  Zimbabwe corr :  [ 0.34006291  0.34137561  0.30808534  0.32242223]
